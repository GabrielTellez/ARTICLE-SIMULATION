# %%
# Import packages to use
import numpy as np
import pandas as pd
import matplotlib as mpl
import matplotlib.pyplot as plt
import statsmodels.api as sm
import os
import glob
import re
mpl.rcParams['mathtext.fontset'] = 'cm'
mpl.rcParams.update({'errorbar.capsize': 2})
# Out:
# //anaconda/lib/python3.5/site-packages/statsmodels/compat/pandas.py:56: FutureWarning: The pandas.core.datetools module is deprecated and will be removed in a future version. Please use the pandas.tseries module instead.
#   from pandas.core import datetools

# %%
# Create data frame to store data
data=pd.DataFrame({'beta': [],'nu_mean': [],'nu_std': []})

# Check every .csv file in the folder
for filename in glob.glob('*.csv'):
    # Import specific file
    df=pd.read_csv(filename, engine='python')
    
    # Get mean coefficient, deviation and beta from the file 
    mui=df['log_t'].mean()
    si=df['log_t'].std()
    bi=float(re.findall("[-+]?\d*\.\d+|\d+",filename)[1])
    
    # Create auxiliar data frame with extracted data
    aux=pd.DataFrame({'beta': [bi],'nu_mean': [mui],'nu_std': [si]})
    
    # Append auxiliar data frame to original data
    data=data.append(aux,ignore_index=True,sort=True)

# %%
plt.figure(figsize=(12,6))

plt.errorbar(data.beta,-data.nu_mean,data.nu_std,
             fmt='o',markersize=4,label='Simulated Data',c='blue')

betaplot=np.linspace(1,max(data['beta']),1000)
nuplot=np.divide(1.0,1.0+betaplot)
plt.plot(betaplot,nuplot,color='red',linestyle='--',label='Theoretical data')

plt.title(r'$N=100\quad\ell_f=0.5$',fontsize=30)
plt.xlabel(r'$\beta$',fontsize=30)
plt.ylabel(r'$\nu$',fontsize=30)

plt.grid(zorder=3)
plt.legend(fontsize=20)
plt.show()
plt.close()

# %%
plt.figure(figsize=(12,6))

plt.errorbar(data.beta,data.nu_mean,data.nu_std,
             fmt='o',markersize=4,label='Simulated Data',c='blue')

betaplot=np.linspace(1,max(data['beta']),1000)
nuplot=np.divide(-1.0,1.0+betaplot)
plt.plot(betaplot,nuplot,color='red',linestyle='--',label='Theoretical data')

plt.title(r'$N=100\quad\ell_f=0.5$',fontsize=30)
plt.xlabel(r'$\beta$',fontsize=30)
plt.ylabel(r'$\nu$',fontsize=30)

plt.grid(zorder=3)
plt.legend(fontsize=20)
plt.show()
plt.close()

# %%
df
# Out:
#         lmin      lmax     const  const_err     log_t  log_t_err
# 0  -3.267781 -0.545137  2.736997   0.000023 -0.320803   0.000015
# 1  -3.746066 -0.357826  2.738231   0.000022 -0.319247   0.000015
# 2  -3.582893 -0.908873  2.746043   0.000037 -0.315880   0.000020
# 3  -4.072044 -1.358390  2.761249   0.000060 -0.308985   0.000026
# 4  -3.006794 -0.706767  2.736782   0.000026 -0.321414   0.000016
# 5  -3.720975 -0.201132  2.738026   0.000017 -0.319397   0.000012
# 6  -2.894849 -0.479508  2.735023   0.000016 -0.322565   0.000012
# 7  -4.490446 -0.104058  2.739718   0.000020 -0.317288   0.000015
# 8  -3.028855 -2.221690  2.765344   0.000088 -0.309008   0.000034
# 9  -4.072235 -0.584934  2.741715   0.000035 -0.316990   0.000021
# 10 -3.501553 -1.327857  2.755010   0.000045 -0.312217   0.000021
# 11 -4.191435 -1.924395  2.780255   0.000088 -0.302332   0.000032
# 12 -3.090667 -0.778484  2.738562   0.000028 -0.320348   0.000017
# 13 -3.860622 -2.266335  2.788257   0.000101 -0.300133   0.000035
# 14 -3.767448 -0.954771  2.748712   0.000040 -0.314411   0.000021
# 15 -4.049451 -1.576736  2.766793   0.000072 -0.307022   0.000029
# 16 -4.479082 -0.481243  2.742146   0.000035 -0.316117   0.000022
# 17 -3.452247 -1.619588  2.760440   0.000060 -0.310188   0.000026
# 18 -3.933390 -2.254619  2.788818   0.000101 -0.299891   0.000035
# 19 -2.891922 -0.322593  2.735135   0.000012 -0.322500   0.000010
# 20 -3.003525 -0.262806  2.735729   0.000012 -0.321967   0.000009
# 21 -3.877141 -2.156087  2.784071   0.000098 -0.301444   0.000035
# 22 -2.669788 -1.848052  2.753122   0.000038 -0.314137   0.000017
# 23 -4.132982 -1.049565  2.753994   0.000048 -0.311673   0.000024
# 24 -4.322485 -1.343306  2.763324   0.000065 -0.307867   0.000028
# 25 -4.367081 -1.744586  2.776382   0.000087 -0.303346   0.000033
# 26 -4.343957 -1.320067  2.762979   0.000064 -0.307959   0.000028
# 27 -2.787504 -2.130492  2.756647   0.000079 -0.312580   0.000033
# 28 -4.425702 -1.021446  2.755344   0.000054 -0.310694   0.000026
# 29 -4.022196 -1.706988  2.770887   0.000075 -0.305638   0.000030
# 30 -2.594964 -1.678797  2.749801   0.000032 -0.315615   0.000016
# 31 -3.590111 -2.208236  2.781398   0.000106 -0.302598   0.000038
# 32 -3.655679 -0.587356  2.739630   0.000030 -0.318705   0.000019
# 33 -3.758945 -1.984065  2.776119   0.000087 -0.304178   0.000033
# 34 -3.607072 -1.990279  2.773997   0.000086 -0.305075   0.000033
# 35 -2.532544 -1.155892  2.742497   0.000022 -0.319122   0.000013
# 36 -3.030044 -0.168674  2.736299   0.000010 -0.321571   0.000009
# 37 -3.694446 -1.121173  2.752162   0.000043 -0.313074   0.000021
# 38 -3.207070 -0.626377  2.737413   0.000025 -0.320705   0.000016
# 39 -3.959898 -0.527544  2.740390   0.000031 -0.317801   0.000019
# 40 -3.545640 -1.633133  2.762255   0.000065 -0.309352   0.000028
# 41 -2.559828 -1.813497  2.751992   0.000043 -0.314647   0.000020
# 42 -2.479383 -1.166649  2.742386   0.000023 -0.319216   0.000013
# 43 -4.013438 -0.193107  2.738801   0.000019 -0.318507   0.000014
# 44 -2.673764 -1.826348  2.752692   0.000037 -0.314318   0.000017
# 45 -3.708879 -0.589102  2.739937   0.000031 -0.318458   0.000019
# 46 -4.402283 -0.459681  2.741525   0.000033 -0.316533   0.000021
# 47 -3.237905 -0.936102  2.743992   0.000029 -0.317456   0.000016
# 48 -2.519398 -0.298222  2.734315   0.000010 -0.323543   0.000009
# 49 -4.402357 -1.229489  2.760898   0.000062 -0.308630   0.000028
